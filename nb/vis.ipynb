# %%
import rasterio
from matplotlib import pyplot
from rasterio.plot import show, show_hist

# %%
with rasterio.open("../test_samples/n50e115_dem_fixed1.tif") as ds:
  show(ds.read(), cmap='viridis')

# %%
ds = rasterio.open("../test_samples/index.vrt")

# %%
show(ds.read(), cmap='viridis')
# Out:
# <Axes: >

# %%
fig, ax = pyplot.subplots(1, figsize=(12, 12))
show((ds, 1), cmap='Greys_r', interpolation='none', ax=ax)
show((ds, 1), contour=True, ax=ax)
# Out:
# <Axes: >
